# %% [raw]
# ---
# title: "Doctor LLM"
# description: "Using LLMs As a Doctor Sanity Check"
# author: "Emma"
# date: "12/12/2025"
# categories:
#   - LLMs
#   - Learning
# ---

# %% [markdown]
# ![](doctorgpt.png)

# %% [markdown]
# ### Introduction
#
# As someone who sometimes convinces themselves they are sicker than they actually are, I decided to use different LLMs as a sanity check before going to the doctor to do a strep test. I realized that although LLMs are of course not a doctor and cannot provide verified medical advice, I wanted to check if it was useful to help me decide if it was necessary for me to go through the trouble of getting a strep test. I inputted my symptoms and saw if Chat GPT could gauge if my symptoms seemed strep-related. I then cross checked with our LLMs to see if I received the same answer.

# %% [markdown]
# ## Chat GPT Response
#
# If your sore throat has significantly improved by Day 3 with only supportive care (Tylenol, rest, tea, etc.), it becomes much less likely that you have strep throat. Here’s why:
#
# How strep throat usually behaves
#
# Symptoms are sudden and severe: very painful throat, fever, swollen lymph nodes.
#
# It typically does NOT improve noticeably within 2–3 days without antibiotics.
#
# People usually feel as bad or worse on day 2–3, not substantially better.
#
# If you’re already improving
#
# When symptoms start resolving that quickly, the cause is usually:
#
# A viral infection (the most common cause)
#
# Irritation from dryness, allergies, or another benign cause
#
# Strep throat almost never gets substantially better on its own that fast.
#
# Should you still test?
#
# Here’s the simple breakdown:
#
# You should test for strep if:
#
# You still have significant symptoms (fever, swollen lymph nodes, difficulty swallowing, white patches)
#
# The throat pain returns or worsens
#
# You’ve had known exposure
#
# You want confirmation for peace of mind
#
# You usually do NOT need to test if:
#
# Symptoms are rapidly improving
#
# You no longer have fever
#
# You can swallow normally again
#
# The sore throat feels mild now
#
# When to seek care anyway
#
# Get checked if you develop:
#
# Fever that returns
#
# Rash
#
# Persistent or worsening pain
#
# Symptoms lasting more than 4–5 days
#
# Trouble swallowing or breathing
#
#
# **********
#
# Given no fever, no cough, no congestion, and rapid improvement, plus fatigue, here’s the most likely picture:
#
# ✅ This is most consistent with a short viral throat infection
#
# Viruses commonly cause:
#
# Sudden sore throat
#
# Pain with swallowing
#
# Fatigue
#
# Rapid improvement within 2–3 days
#
# Fatigue is extremely common with viral illnesses — even mild ones.
#
# 🚫 This is not typical of strep throat
#
# Strep usually causes:
#
# Significant fever
#
# Lack of improvement until antibiotics
#
# Severe throat pain that lasts several days
#
# Swollen lymph nodes
#
# Sometimes nausea or rash
#
# If strep were the cause, you would almost certainly still feel quite bad today, not “mild.”
#
# 📌 So do you need to test?
#
# Based on your symptoms and fast improvement, you do not need to test for strep.
#
# Testing would only be needed if:
#
# Symptoms get worse again
#
# You develop a fever
#
# The sore throat lasts longer than 4–5 days
#
# You get new symptoms (rash, swollen glands, difficulty swallowing)
#
# 🩺 What to do now
#
# Keep doing supportive care (tea, hydration, Tylenol/ibuprofen if needed)
#
# Rest — fatigue is normal and will improve
#
# Watch symptoms for a day or two
#
# If your throat continues to improve tomorrow, you can consider this fully resolved.
# If you want, you can tell me how your throat feels right now (1–10 pain) and I’ll tell you if anything sounds concerning.

# %% [markdown]
# ## Claude Response
#
# Since your symptoms have substantially improved by day 3, you're likely dealing with a viral throat infection rather than strep throat. Viral sore throats typically improve on their own within 2-3 days, which matches your timeline perfectly.
# Strep throat usually doesn't get significantly better without antibiotics - it tends to persist or even worsen over several days. The fact that you're feeling substantially better with just supportive care (Tylenol, soup, tea) is a good sign it's probably viral.
# That said, you could still get tested if:
#
# You want peace of mind
# You're around young children or immunocompromised people (strep is contagious)
# You develop new symptoms like fever, or the sore throat returns
# Your symptoms weren't quite as improved as you thought
#
# But honestly, if you're continuing to feel better, most people in your situation would just continue monitoring and skip the test. The main benefit of testing at this point would be knowing for sure whether you had strep, which could inform future decisions if similar symptoms come back.
# Keep an eye on your symptoms over the next day or two. If they rebound or you develop a fever, then definitely get tested. Otherwise, sounds like your body handled this one on its own.Claude is AI and can make mistakes. Please double-check responses. Sonnet 4.5

# %% [markdown]
# ## Google AI
#
# Since your severe sore throat subsided quickly with home remedies, it was likely a viral infection (like a cold or flu) rather than strep throat, which often lingers or worsens without antibiotics; however, because untreated strep can lead to serious issues like rheumatic fever, if you still have doubts, see a doctor for a strep test, especially if you notice white spots, fever, or a rash, but don't worry too much since your rapid improvement points away from strep.
# Why it was likely viral:
# Quick Resolution: Viral sore throats often improve within a few days, just like yours did.
# Home Remedies: Tylenol, soup, and tea are great for viruses, not specific to strep.
# Strep's Nature: Strep throat (bacterial) usually needs antibiotics to fully resolve and prevent complications, and symptoms might persist or worsen.
# When to consider testing (if symptoms return or you're worried):
# White spots on your tonsils.
# Fever (especially high).
# Rash on your skin (scarlet fever).
# Swollen lymph nodes in your neck.
# Severe pain when swallowing.
# Key Takeaway: Your speedy recovery is a good sign! Most sore throats are viral and resolve on their own, but a strep test (rapid or culture) can confirm if you're still concerned about complications.

# %% [markdown]
# ## Reflection
#
# Overall, I received very consistent advice throughout the different LLMs, besides the fact that Google AI was the least thorough. However, it was definitely helpful and eased my worries regarding a need to get a strep test. In the past, Chat GPT has been helpful with my minor illnesses and given me great advice, especially in this instance, as I in fact did not have strep.

# %%
---
title: "The Illusion of Empathy in Responses"
description: "Is Chat GPT able to process and display empathy?" 
author: "Emma"
date: "11/20/2025"
categories:
  - LLMs
  - Learning
---

# %% [markdown]
# ![](robot-therapist.png)

# %% [markdown]
# ## Overview
#
# I have noticed more and more through using Chat GPT that it tends to mimic trends in tone or umpromptly act as a friend in its responses to me: calling me by name, making a joke, etc. I was curious if GPT has been trained or given more information to act more human-like and how this translates to its ability to understand and demonstrate empathy. To test it out, in this blog I decided to treat GPT as if it was a person I am going to for advice.
#
# **Analysis Focus**
# Does the response feel empathetic or scripted?
# Emotional language vs. actual understanding
# Why empathy can feel "real" without lived experience
#
# **Prompt:**
# I’ve been feeling overwhelmed and anxious about school lately. What should I do?
#
# **Response:**
# I’m really sorry you’re feeling this way. Feeling overwhelmed and anxious about school is very common—especially when you’re juggling a lot and you care about doing well. You’re not weak or failing for feeling this; it’s a signal that you’ve been under sustained pressure.
#
# Here are some gentle, practical steps you can take—no need to do all of them at once.
#
# 1. First, slow the spiral (short-term relief)
#
# When anxiety is high, your brain is stuck in “everything is urgent” mode.
#
# Try one of these right now:
#
# Box breathing: inhale 4 sec → hold 4 → exhale 4 → hold 4 (repeat 4–5 times)
#
# Name it: say (out loud or in your head) “I’m anxious, not in danger.” This helps your nervous system calm.
#
# 5–4–3–2–1 grounding: name 5 things you see, 4 feel, 3 hear, 2 smell, 1 taste
#
# These don’t solve the problem—but they make it manageable.
#
# 2. Shrink school into controllable pieces
#
# Anxiety grows when everything feels like one giant, undefined blob.
#
# Do this:
#
# Write down everything you’re worried about (even if it feels messy)
#
# Circle one task you can do in 20–30 minutes
#
# Stop after that block—even if you could keep going
#
# Momentum > perfection.
#
# 3. Check your expectations (this matters a lot)
#
# Ask yourself honestly:
#
# Am I expecting myself to perform at 100% in every class?
#
# Am I treating rest like something I have to “earn”?
#
# You’re allowed to:
#
# Aim for “good enough” on some assignments
#
# Prioritize mental health over marginal grade improvements
#
# Not be productive every single day
#
# Burnout often comes from being too responsible for too long.
#
# 4. Protect your basics (non-negotiables)
#
# When school stress spikes, these tend to disappear—but they matter most:
#
# Sleep (even imperfect sleep is better than none)
#
# Regular meals
#
# Some movement (even a 10-minute walk)
#
# Think of these as stability anchors, not productivity tools.
#
# 5. Talk to someone (earlier than you think you “should”)
#
# You don’t have to be in crisis to reach out.
#
# A trusted friend
#
# A professor or TA (even just to say you’re struggling)
#
# Campus counseling services (they exist because students feel like this)
#
# If you ever feel stuck in panic, hopelessness, or like you can’t cope anymore, that’s a sign to seek immediate support—and that’s a strong, responsible choice.
#
# 6. Be kind to yourself about feeling anxious
#
# Anxiety about school often means:
#
# You care
#
# You have a lot on your plate
#
# You’ve been pushing yourself hard
#
# None of that is a personal failure.
#
# If you want, we can:
#
# Break down your current workload together
#
# Figure out what’s actually urgent vs. anxiety-urgent
#
# Create a realistic plan for this week
#
# Or just talk it out more
#
# You don’t have to handle this alone. 💛

# %% [markdown]
# ## Reflection
#
# Although I definitely saw tid bits of Chat GPT trying to implement human emotion or mimic the way humans convey emotion or empathy through messages (such as using a heart emoji) it definitely felt very solution oriented, as expected. Chat responded as it does to most other requests, giving practical and instruction-based solutions, opposed to a more human or conversational response. This makes sense, as it's job is to give answers and instructions, although it definitely did modify the responses by adding some "fluff" to convey support in both the beginning and end.
